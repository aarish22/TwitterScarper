# %%
# !pip install ntscraper
from ntscraper import Nitter
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.13-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2024.2.2)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.13

# %%
scraper = Nitter(log_level = 1,skip_instance_check = False)
# Out:
# Testing instances: 100%|██████████| 77/77 [01:55<00:00,  1.49s/it]

# %%
tweets = scraper.get_tweets("ChampionsLeague",mode="user",number=10)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.esmailelbob.xyz
# INFO:root:Current stats for ChampionsLeague: 10 tweets, 0 threads...

# %%
from pprint import pprint

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'Mar 4, 2024 · 11:00 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': True,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1764606719785869424#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 4738,
#                        'likes': 40398,
#                        'quotes': 10099,
#                        'retweets': 8561},
#              'text': 'An exciting new era for European club football awaits 🤩  '
#                      'Here’s how the #UCL will look from 2024/25 👇',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': ['https://video.twimg.com/amplify_video/1764602415754440704/pl/yPJ_wFXF1gapmEWa.m3u8?tag=16&container=cmaf']},
#             {'date': 'Apr 16, 2024 · 7:59 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780325263752011983#m',
#              'pictures': ['https://pbs.twimg.com/media/GLT8KyjWkAA8SHr.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 121,
#                        'likes': 1618,
#                        'quotes': 18,
#                        'retweets': 127},
#              'text': 'A huge 45 minutes to come... ⏱️ (Agg: 4-3)   #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:58 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780324972096860232#m',
#              'pictures': ['https://pbs.twimg.com/media/GLT7_2XWAAAGjMh.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 81,
#                        'likes': 2564,
#                        'quotes': 30,
#                        'retweets': 165},
#              'text': 'Dortmund have turned the tie on its head 🥵 (Agg: 3-2)   '
#                      '#UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:30 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780317973120487480#m',
#              'pictures': ['https://pbs.twimg.com/media/GLT1pvUXIAI3yPk.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 94,
#                        'likes': 6106,
#                        'quotes': 8,
#                        'retweets': 354},
#              'text': 'Yamal x Raphinha 🔥  #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:13 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780313675145871679#m',
#              'pictures': ['https://pbs.twimg.com/media/GLTxNcmXwAAu5bI.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 87,
#                        'likes': 2837,
#                        'quotes': 3,
#                        'retweets': 131},
#              'text': '👊  #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:11 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780313118125576486#m',
#              'pictures': ['https://pbs.twimg.com/media/GLTxTbrW8AAJmJD.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 130,
#                        'likes': 5418,
#                        'quotes': 26,
#                        'retweets': 300},
#              'text': 'That Azpilicueta block 😮  #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:00 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780310194133586420#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 63,
#                        'likes': 676,
#                        'quotes': 4,
#                        'retweets': 62},
#              'text': 'Barcelona 🆚 Paris Dortmund 🆚 Altético  #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 6:33 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780303606303838344#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 106,
#                        'likes': 2833,
#                        'quotes': 16,
#                        'retweets': 240},
#              'text': 'Style, style, style 👔  @JustEatTakeaway || #UCLprematch',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': ['https://video.twimg.com/amplify_video/1780302949194903553/pl/SmoCqM_omy1d-VAO.m3u8?tag=16&container=cmaf']},
#             {'date': 'Apr 16, 2024 · 6:05 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780296416620884352#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 82,
#                        'likes': 611,
#                        'quotes': 1,
#                        'retweets': 50},
#              'text': '🎙️ Follow Barcelona vs Paris with #MatchdayLive ⚽️ '
#                      'Updates from Dortmund vs Atlético',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []},
#             {'date': 'Apr 16, 2024 · 7:00 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': True,
#              'link': 'https://twitter.com/ChampionsLeague/status/1780128998829539441#m',
#              'pictures': ['https://pbs.twimg.com/media/GLNg5xuXoAA67tZ.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 382,
#                        'likes': 26200,
#                        'quotes': 331,
#                        'retweets': 2763},
#              'text': 'We go again 🤩  #UCL',
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg',
#                       'name': 'UEFA Champions League',
#                       'profile_id': '1417052605776375813',
#                       'username': '@ChampionsLeague'},
#              'videos': []}]}

# %%
tweets.keys()
# Out:
# dict_keys(['tweets', 'threads'])

# %%
tweets['tweets'][0]
# Out:
# {'link': 'https://twitter.com/ChampionsLeague/status/1764606719785869424#m',
#  'text': 'An exciting new era for European club football awaits 🤩  Here’s how the #UCL will look from 2024/25 👇',
#  'user': {'name': 'UEFA Champions League',
#   'username': '@ChampionsLeague',
#   'profile_id': '1417052605776375813',
#   'avatar': 'https://pbs.twimg.com/profile_images/1417052605776375813/Jc9RL5o7_bigger.jpg'},
#  'date': 'Mar 4, 2024 · 11:00 AM UTC',
#  'is-retweet': False,
#  'is-pinned': True,
#  'external-link': '',
#  'replying-to': [],
#  'quoted-post': {},
#  'stats': {'comments': 4738,
#   'retweets': 8561,
#   'quotes': 10099,
#   'likes': 40398},
#  'pictures': [],
#  'videos': ['https://video.twimg.com/amplify_video/1764602415754440704/pl/yPJ_wFXF1gapmEWa.m3u8?tag=16&container=cmaf'],
#  'gifs': []}

# %%
data ={
    'link':[],
    'text':[],
    'user':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[]
}
for tweet in tweets['tweets']:
  data['link'].append(tweet['link'])
  data['text'].append(tweet['text'])
  data['user'].append(tweet['user']['name'])
  data['likes'].append(tweet['stats']['likes'])
  data['quotes'].append(tweet['stats']['quotes'])
  data['retweets'].append(tweet['stats']['retweets'])
  data['comments'].append(tweet['stats']['comments'])

# %%
data
# Out:
# {'link': ['https://twitter.com/ChampionsLeague/status/1764606719785869424#m',
#   'https://twitter.com/ChampionsLeague/status/1780325263752011983#m',
#   'https://twitter.com/ChampionsLeague/status/1780324972096860232#m',
#   'https://twitter.com/ChampionsLeague/status/1780317973120487480#m',
#   'https://twitter.com/ChampionsLeague/status/1780313675145871679#m',
#   'https://twitter.com/ChampionsLeague/status/1780313118125576486#m',
#   'https://twitter.com/ChampionsLeague/status/1780310194133586420#m',
#   'https://twitter.com/ChampionsLeague/status/1780303606303838344#m',
#   'https://twitter.com/ChampionsLeague/status/1780296416620884352#m',
#   'https://twitter.com/ChampionsLeague/status/1780128998829539441#m'],
#  'text': ['An exciting new era for European club football awaits 🤩  Here’s how the #UCL will look from 2024/25 👇',
#   'A huge 45 minutes to come... ⏱️ (Agg: 4-3)   #UCL',
#   'Dortmund have turned the tie on its head 🥵 (Agg: 3-2)   #UCL',
#   'Yamal x Raphinha 🔥  #UCL',
#   '👊  #UCL',
#   'That Azpilicueta block 😮  #UCL',
#   'Barcelona 🆚 Paris Dortmund 🆚 Altético  #UCL',
#   'Style, style, style 👔  @JustEatTakeaway || #UCLprematch',
#   '🎙️ Follow Barcelona vs Paris with #MatchdayLive ⚽️ Updates from Dortmund vs Atlético',
#   'We go again 🤩  #UCL'],
#  'user': ['UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League',
#   'UEFA Champions League'],
#  'likes': [40398, 1618, 2564, 6106, 2837, 5418, 676, 2833, 611, 26200],
#  'quotes': [10099, 18, 30, 8, 3, 26, 4, 16, 1, 331],
#  'retweets': [8561, 127, 165, 354, 131, 300, 62, 240, 50, 2763],
#  'comments': [4738, 121, 81, 94, 87, 130, 63, 106, 82, 382]}

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/ChampionsLeague/status/176...
# 1  https://twitter.com/ChampionsLeague/status/178...
# 2  https://twitter.com/ChampionsLeague/status/178...
# 3  https://twitter.com/ChampionsLeague/status/178...
# 4  https://twitter.com/ChampionsLeague/status/178...
#
#                                                 text                   user  \
# 0  An exciting new era for European club football...  UEFA Champions League
# 1  A huge 45 minutes to come... ⏱️ (Agg: 4-3)   #UCL  UEFA Champions League
# 2  Dortmund have turned the tie on its head 🥵 (Ag...  UEFA Champions League
# 3                           Yamal x Raphinha 🔥  #UCL  UEFA Champions League
# 4                                            👊  #UCL  UEFA Champions League
#
#    likes  quotes  retweets  comments
# 0  40398   10099      8561      4738
# 1   1618      18       127       121
# 2   2564      30       165        81
# 3   6106       8       354        94
# 4   2837       3       131        87

# %%
df.to_csv('UCL_data.csv')
